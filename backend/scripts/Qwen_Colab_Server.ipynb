# %% [markdown]
# # ⚡ Emiot - Qwen3 8B Instruct Colab Server
#
# Serves **Qwen3 8B Instruct** from Google Colab GPU via vLLM and ngrok directly to Emiot!

# %%
# Step 1: Install vLLM and ngrok
# !pip install -q vllm pyngrok

# %%
# Step 2: Set your ngrok authtoken (Get free token at https://dashboard.ngrok.com/get-started/your-authtoken)
import os
from pyngrok import ngrok

NGROK_TOKEN = "YOUR_NGROK_AUTHTOKEN_HERE"
if NGROK_TOKEN != "YOUR_NGROK_AUTHTOKEN_HERE":
    ngrok.set_auth_token(NGROK_TOKEN)
    tunnel = ngrok.connect(8000)
    print(f"🚀 PUBLIC EMIOT QWEN URL: {tunnel.public_url}/v1/chat/completions")
    print(f"📌 Copy this URL to Emiot's backend configuration!")

# %%
# Step 3: Run vLLM OpenAI-Compatible Server for Qwen3 8B Instruct
# !python -m vllm.entrypoints.openai.api_server \
    --model Qwen/Qwen3-8B-Instruct \
    --port 8000 \
    --max-model-len 4096 \
    --gpu-memory-utilization 0.90
